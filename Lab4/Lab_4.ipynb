# %%
covid_cat = covid.select_dtypes(object)
covid_cat.head()
# Out:
#   Country_Region    Last_Update Combined_Key
# 0    Afghanistan  1/2/2021 5:22  Afghanistan
# 1        Albania  1/2/2021 5:22      Albania
# 2        Algeria  1/2/2021 5:22      Algeria
# 3        Andorra  1/2/2021 5:22      Andorra
# 4         Angola  1/2/2021 5:22       Angola

# %%
covid_num = covid.select_dtypes(np.number)
covid_num.head()
# Out:
#         Lat      Long_  Confirmed  Deaths  Recovered  Active  Incident_Rate  \
# 0  33.93911  67.709953      52513    2201      41727    8585     134.896578
# 1  41.15330  20.168300      58316    1181      33634   23501    2026.409062
# 2  28.03390   1.659600      99897    2762      67395   29740     227.809861
# 3  42.50630   1.521800       8117      84       7463     570   10505.403480
# 4 -11.20270  17.873900      17568     405      11146    6017      53.452981
#
#    Case_Fatality_Ratio
# 0             4.191343
# 1             2.025173
# 2             2.764848
# 3             1.034865
# 4             2.305328

# %%
import pandas as pd
covid_cat = covid.select_dtypes(object)
covid_cat.drop(['Last_Update','Combined_Key'], axis=1, inplace=True)
covid.head()
# Out:
#   Country_Region    Last_Update       Lat      Long_  Confirmed  Deaths  \
# 0    Afghanistan  1/2/2021 5:22  33.93911  67.709953      52513    2201
# 1        Albania  1/2/2021 5:22  41.15330  20.168300      58316    1181
# 2        Algeria  1/2/2021 5:22  28.03390   1.659600      99897    2762
# 3        Andorra  1/2/2021 5:22  42.50630   1.521800       8117      84
# 4         Angola  1/2/2021 5:22 -11.20270  17.873900      17568     405
#
#    Recovered  Active Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 0      41727    8585  Afghanistan     134.896578             4.191343
# 1      33634   23501      Albania    2026.409062             2.025173
# 2      67395   29740      Algeria     227.809861             2.764848
# 3       7463     570      Andorra   10505.403480             1.034865
# 4      11146    6017       Angola      53.452981             2.305328

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021 (1).csv")
covid_cat = covid.select_dtypes(object)
covid_num = covid.select_dtypes(np.number)
covid.head()
covid_cat.drop(['Last_Update', 'Combined_Key'], axis=1, inplace=True)
covid.head()
# Out:
#   Country_Region    Last_Update       Lat      Long_  Confirmed  Deaths  \
# 0    Afghanistan  1/2/2021 5:22  33.93911  67.709953      52513    2201
# 1        Albania  1/2/2021 5:22  41.15330  20.168300      58316    1181
# 2        Algeria  1/2/2021 5:22  28.03390   1.659600      99897    2762
# 3        Andorra  1/2/2021 5:22  42.50630   1.521800       8117      84
# 4         Angola  1/2/2021 5:22 -11.20270  17.873900      17568     405
#
#    Recovered  Active Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 0      41727    8585  Afghanistan     134.896578             4.191343
# 1      33634   23501      Albania    2026.409062             2.025173
# 2      67395   29740      Algeria     227.809861             2.764848
# 3       7463     570      Andorra   10505.403480             1.034865
# 4      11146    6017       Angola      53.452981             2.305328

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021 (1).csv")
covid_cat = covid.select_dtypes(object)
covid_cat.drop(['Last_Update', 'Combined_Key'], axis=1, inplace=True)
print(covid.dtypes)
# Out:
# Country_Region          object
# Last_Update             object
# Lat                    float64
# Long_                  float64
# Confirmed                int64
# Deaths                   int64
# Recovered                int64
# Active                   int64
# Combined_Key            object
# Incident_Rate          float64
# Case_Fatality_Ratio    float64
# dtype: object

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021_2.csv")
covid_cat = covid.select_dtypes(object)
covid_num = covid.select_dtypes(np.number)
covid.head()
# Out:
#   Country_Region  Confirmed  Deaths  Recovered
# 0    Afghanistan      52513    2201      41727
# 1        Albania      58316    1181      33634
# 2        Algeria      99897    2762      67395
# 3        Andorra       8117      84       7463
# 4         Angola      17568     405      11146

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021_2.csv")
covid_cat = covid.select_dtypes(object)
covid_num = covid.select_dtypes(np.number)
covid.head()
covid_cat.isnull().sum()
# Out:
# Country_Region    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
covid_cat = covid_cat.apply(le.fit_transform)

# %%
covid_num.isna().sum()
# Out:
# Confirmed    0
# Deaths       0
# Recovered    0
# dtype: int64

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021_2.csv")
covid_cat = covid.select_dtypes(object)
covid_num = covid.select_dtypes(np.number)
covid.head()
covid_cat.isnull().sum()
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
covid_cat = covid_cat.apply(le.fit_transform)
covid_final = pd.concat([covid_cat,covid_num], axis=1)
covid_final.head()
# Out:
#    Country_Region  Confirmed  Deaths  Recovered
# 0               0      52513    2201      41727
# 1               1      58316    1181      33634
# 2               2      99897    2762      67395
# 3               3       8117      84       7463
# 4               4      17568     405      11146

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021_2.csv")
covid_cat = covid.select_dtypes(object)
covid_num = covid.select_dtypes(np.number)
covid.head()
covid_cat.isnull().sum()
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
covid_cat = covid_cat.apply(le.fit_transform)
covid_final = pd.concat([covid_cat,covid_num], axis=1)
covid_final.head()
X = covid_final.drop(['Deaths'], axis=1)
Y = covid_final['Deaths']

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021_2.csv")
covid_cat = covid.select_dtypes(object)
covid_num = covid.select_dtypes(np.number)
covid.head()
covid_cat.isnull().sum()
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
covid_cat = covid_cat.apply(le.fit_transform)
covid_final = pd.concat([covid_cat,covid_num], axis=1)
covid_final.head()
X = covid_final.drop(['Deaths'], axis=1)
Y = covid_final['Deaths']
X_train = np.array(X[0:int(0.80*len(X))])
Y_train = np.array(Y[0:int(0.80*len(Y))])
X_test = np.array(X[int(0.80*len(X)):])
Y_test = np.array(Y[int(0.80*len(Y)):])
len(X_train), len(Y_train), len(X_test), len(Y_test)
# Out:
# (3208, 3208, 803, 803)

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021_2.csv")
covid_cat = covid.select_dtypes(object)
covid_num = covid.select_dtypes(np.number)
covid.head()
covid_cat.isnull().sum()
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
covid_cat = covid_cat.apply(le.fit_transform)
covid_final = pd.concat([covid_cat,covid_num], axis=1)
covid_final.head()
X = covid_final.drop(['Deaths'], axis=1)
Y = covid_final['Deaths']
X_train = np.array(X[0:int(0.80*len(X))])
Y_train = np.array(Y[0:int(0.80*len(Y))])
X_test = np.array(X[int(0.80*len(X)):])
Y_test = np.array(Y[int(0.80*len(Y)):])
len(X_train), len(Y_train), len(X_test), len(Y_test)
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
LR = LogisticRegression()
KNN = KNeighborsClassifier()
NB = GaussianNB()
LSVM = LinearSVC()
NLSVM = SVC(kernel='rbf')
DT = DecisionTreeClassifier()
RF = RandomForestClassifier()
LR_fit = LR.fit(X_train, Y_train)
KNN_fit = KNN.fit(X_train, Y_train)
NB_fit = NB.fit(X_train, Y_train)
LSVM_fit = LSVM.fit(X_train, Y_train)
NLSVM_fit = NLSVM.fit(X_train, Y_train)
DT_fit = DT.fit(X_train, Y_train)
RF_fit = RF.fit(X_train, Y_train)
LR_pred = LR_fit.predict(X_test)
KNN_pred = KNN_fit.predict(X_test)
NB_pred = NB_fit.predict(X_test)
LSVM_pred = LSVM_fit.predict(X_test)
NLSVM_pred = NLSVM_fit.predict(X_test)
DT_pred = DT_fit.predict(X_test)
RF_pred = RF_fit.predict(X_test)
# Out:
# C:\Users\silen\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\silen\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021_2.csv")
covid_cat = covid.select_dtypes(object)
covid_num = covid.select_dtypes(np.number)
covid.head()
covid_cat.isnull().sum()
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
covid_cat = covid_cat.apply(le.fit_transform)
covid_final = pd.concat([covid_cat,covid_num], axis=1)
covid_final.head()
X = covid_final.drop(['Deaths'], axis=1)
Y = covid_final['Deaths']
X_train = np.array(X[0:int(0.80*len(X))])
Y_train = np.array(Y[0:int(0.80*len(Y))])
X_test = np.array(X[int(0.80*len(X)):])
Y_test = np.array(Y[int(0.80*len(Y)):])
len(X_train), len(Y_train), len(X_test), len(Y_test)
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
LR = LogisticRegression()
KNN = KNeighborsClassifier()
NB = GaussianNB()
LSVM = LinearSVC()
NLSVM = SVC(kernel='rbf')
DT = DecisionTreeClassifier()
RF = RandomForestClassifier()
LR_fit = LR.fit(X_train, Y_train)
KNN_fit = KNN.fit(X_train, Y_train)
NB_fit = NB.fit(X_train, Y_train)
LSVM_fit = LSVM.fit(X_train, Y_train)
NLSVM_fit = NLSVM.fit(X_train, Y_train)
DT_fit = DT.fit(X_train, Y_train)
RF_fit = RF.fit(X_train, Y_train)
LR_pred = LR_fit.predict(X_test)
KNN_pred = KNN_fit.predict(X_test)
NB_pred = NB_fit.predict(X_test)
LSVM_pred = LSVM_fit.predict(X_test)
NLSVM_pred = NLSVM_fit.predict(X_test)
DT_pred = DT_fit.predict(X_test)
RF_pred = RF_fit.predict(X_test)
from sklearn.metrics import accuracy_score
print("Logistic Regression is %f percent accurate" % (accuracy_score(LR_pred, Y_test)*100))
print("KNN is %f percent accurate" % (accuracy_score(KNN_pred, Y_test)*100))
print("Naive Bayes is %f percent accurate" % (accuracy_score(NB_pred, Y_test)*100))
print("Linear SVMs is %f percent accurate" % (accuracy_score(LSVM_pred, Y_test)*100))
print("Non Linear SVMs is %f percent accurate" % (accuracy_score(NLSVM_pred, Y_test)*100))
print("Decision Trees is %f percent accurate" % (accuracy_score(DT_pred, Y_test)*100))
print("Random Forests is %f percent accurate" % (accuracy_score(RF_pred, Y_test)*100))
# Out:
# C:\Users\silen\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\silen\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Logistic Regression is 5.853051 percent accurate
# KNN is 6.849315 percent accurate
# ...

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021_2.csv")
covid_cat = covid.select_dtypes(object)
covid_num = covid.select_dtypes(np.number)
covid.head()
covid_cat.isnull().sum()
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
covid_cat = covid_cat.apply(le.fit_transform)
covid_final = pd.concat([covid_cat,covid_num], axis=1)
covid_final.head()
X = covid_final.drop(['Deaths'], axis=1)
Y = covid_final['Deaths']
X_train = np.array(X[0:int(0.80*len(X))])
Y_train = np.array(Y[0:int(0.80*len(Y))])
X_test = np.array(X[int(0.80*len(X)):])
Y_test = np.array(Y[int(0.80*len(Y)):])
len(X_train), len(Y_train), len(X_test), len(Y_test)
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
LR = LogisticRegression()
KNN = KNeighborsClassifier()
NB = GaussianNB()
LSVM = LinearSVC()
NLSVM = SVC(kernel='rbf')
DT = DecisionTreeClassifier()
RF = RandomForestClassifier()
LR_fit = LR.fit(X_train, Y_train)
KNN_fit = KNN.fit(X_train, Y_train)
NB_fit = NB.fit(X_train, Y_train)
LSVM_fit = LSVM.fit(X_train, Y_train)
NLSVM_fit = NLSVM.fit(X_train, Y_train)
DT_fit = DT.fit(X_train, Y_train)
RF_fit = RF.fit(X_train, Y_train)
LR_pred = LR_fit.predict(X_test)
KNN_pred = KNN_fit.predict(X_test)
NB_pred = NB_fit.predict(X_test)
LSVM_pred = LSVM_fit.predict(X_test)
NLSVM_pred = NLSVM_fit.predict(X_test)
DT_pred = DT_fit.predict(X_test)
RF_pred = RF_fit.predict(X_test)
from sklearn.metrics import accuracy_score
print("Logistic Regression is %f percent accurate" % (accuracy_score(LR_pred, Y_test)*100))
print("KNN is %f percent accurate" % (accuracy_score(KNN_pred, Y_test)*100))
print("Naive Bayes is %f percent accurate" % (accuracy_score(NB_pred, Y_test)*100))
print("Linear SVMs is %f percent accurate" % (accuracy_score(LSVM_pred, Y_test)*100))
print("Non Linear SVMs is %f percent accurate" % (accuracy_score(NLSVM_pred, Y_test)*100))
print("Decision Trees is %f percent accurate" % (accuracy_score(DT_pred, Y_test)*100))
print("Random Forests is %f percent accurate" % (accuracy_score(RF_pred, Y_test)*100))
from sklearn.metrics import SCORERS, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
seed=0
cv = StratifiedKFold(n_splits=5,random_state=2, shuffle=True)
def return_score(model,X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    return score
scores = []
model = LogisticRegression()
for train_index, test_index in cv.split(X,Y):
    X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)
    score = return_score(model,X_train, X_test, y_train, y_test)    
    scores.append(score)
print("Accuracy score in each iteration: {}".format(scores))
print("StratifedKFold Score: {}".format(np.mean(scores)))
# Out:
# C:\Users\silen\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\silen\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Logistic Regression is 5.853051 percent accurate
# KNN is 6.849315 percent accurate
# ...

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021.csv")

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021.csv")
covid_cat = covid.select_dtypes(object)
covid_num = covid.select_dtypes(np.number)
covid.head()
# Out:
#   Country_Region    Last_Update       Lat      Long_  Confirmed  Deaths  \
# 0    Afghanistan  1/2/2021 5:22  33.93911  67.709953      52513    2201
# 1        Albania  1/2/2021 5:22  41.15330  20.168300      58316    1181
# 2        Algeria  1/2/2021 5:22  28.03390   1.659600      99897    2762
# 3        Andorra  1/2/2021 5:22  42.50630   1.521800       8117      84
# 4         Angola  1/2/2021 5:22 -11.20270  17.873900      17568     405
#
#    Recovered  Active Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 0      41727    8585  Afghanistan     134.896578             4.191343
# 1      33634   23501      Albania    2026.409062             2.025173
# 2      67395   29740      Algeria     227.809861             2.764848
# 3       7463     570      Andorra   10505.403480             1.034865
# 4      11146    6017       Angola      53.452981             2.305328

# %%
import pandas as pd
import numpy as np
covid=pd.read_csv("../Lab4/01-01-2021.csv")
covid_cat = covid.select_dtypes(object)
covid_num = covid.select_dtypes(np.number)
covid.head()
covid_cat.drop(['Last_Update'], axis=1, inplace=True)
covid.head()
# Out:
#   Country_Region    Last_Update       Lat      Long_  Confirmed  Deaths  \
# 0    Afghanistan  1/2/2021 5:22  33.93911  67.709953      52513    2201
# 1        Albania  1/2/2021 5:22  41.15330  20.168300      58316    1181
# 2        Algeria  1/2/2021 5:22  28.03390   1.659600      99897    2762
# 3        Andorra  1/2/2021 5:22  42.50630   1.521800       8117      84
# 4         Angola  1/2/2021 5:22 -11.20270  17.873900      17568     405
#
#    Recovered  Active Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 0      41727    8585  Afghanistan     134.896578             4.191343
# 1      33634   23501      Albania    2026.409062             2.025173
# 2      67395   29740      Algeria     227.809861             2.764848
# 3       7463     570      Andorra   10505.403480             1.034865
# 4      11146    6017       Angola      53.452981             2.305328
